# %% [markdown]
# # PYTHON PROGRAMMING FUNDAMENTALS

# %% [markdown]
# ## Tidy Data
# - each variable is a column
# - each observation is a row
# - each type of observational unit is a table

# %% [markdown]
# ![tidy-data-one.png](attachment:tidy-data-one.png)

# %% [markdown]
# ![tidy-data-two.png](attachment:tidy-data-two.png)

# %% [markdown]
# ![tidy-data-three.png](attachment:tidy-data-three.png)

# %% [markdown]
# 다음 토픽을 설명합니다.
# - Matplotlib
#
# ref:
#
# https://matplotlib.org/gallery.html#scales
#
# https://seaborn.pydata.org/

# %% [markdown]
# ## 가장기본적인 Plot

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(0,20,0.2)

# %%
x
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. , 10.2, 10.4, 10.6, 10.8,
#        11. , 11.2, 11.4, 11.6, 11.8, 12. , 12.2, 12.4, 12.6, 12.8, 13. ,
#        13.2, 13.4, 13.6, 13.8, 14. , 14.2, 14.4, 14.6, 14.8, 15. , 15.2,
#        15.4, 15.6, 15.8, 16. , 16.2, 16.4, 16.6, 16.8, 17. , 17.2, 17.4,
#        17.6, 17.8, 18. , 18.2, 18.4, 18.6, 18.8, 19. , 19.2, 19.4, 19.6,
#        19.8])

# %%
plt.plot(x)
plt.show() # 깔끔하게 표만 나타내는

# %%
y = np.sin(x)

# %%
#  plot을 그리기 위해서는 x,y값이 기본적으로 있어야한다

# %%
plt.plot(x, y)
plt.xlabel('Time')
plt.ylabel('Sine Wave')
plt.title('My First Plot')
plt.show()

# %% [markdown]
# # Bar Charts

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
pokemon = pd.read_csv('pokemon.csv')

# %%
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
pokemon.shape
# Out:
# (807, 14)

# %%
sb.countplot(data = pokemon, x = 'generation_id')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
base_color = sb.color_palette()[0]

# %%
sb.countplot(data = pokemon, x = 'generation_id' , color = base_color, order = [5,1,3,4,2,7,6])
plt.show()

# %% [markdown]
# # Pie Charts

# %%
sorted_count = pokemon.gener

# %% [markdown]
# ## 히스토그램 - 해당 레인지의 갯수

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-28%2002.15.02.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-28%2002.15.02.png)

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               807 non-null    int64
#  1   species          807 non-null    object
#  2   generation_id    807 non-null    int64
#  3   height           807 non-null    float64
#  4   weight           807 non-null    float64
#  5   base_experience  807 non-null    int64
#  6   type_1           807 non-null    object
#  7   type_2           405 non-null    object
#  8   hp               807 non-null    int64
#  9   attack           807 non-null    int64
#  10  defense          807 non-null    int64
#  11  speed            807 non-null    int64
#  12  special-attack   807 non-null    int64
#  13  special-defense  807 non-null    int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 88.4+ KB

# %%
plt.hist(data = pokemon, x = 'speed')
plt.show()

# %%
pokemon.describe()
# Out:
#                id  generation_id      height      weight  base_experience  \
# count  807.000000     807.000000  807.000000  807.000000       807.000000
# mean   404.000000       3.714994    1.162454   61.771128       144.848823
# std    233.105126       1.944148    1.081030  111.519355        74.953116
# min      1.000000       1.000000    0.100000    0.100000        36.000000
# 25%    202.500000       2.000000    0.600000    9.000000        66.000000
# 50%    404.000000       4.000000    1.000000   27.000000       151.000000
# 75%    605.500000       5.000000    1.500000   63.000000       179.500000
# max    807.000000       7.000000   14.500000  999.900000       608.000000
#
#                hp      attack     defense       speed  special-attack  \
# count  807.000000  807.000000  807.000000  807.000000      807.000000
# mean    68.748451   76.086741   71.726146   65.830235       69.486989
# std     26.032808   29.544598   29.730228   27.736838       29.439715
# ...

# %%
plt.hist(data = pokemon, x = 'speed',bins=30)
plt.show()

# %%
bin_width = np.arange(pokemon.speed.min(), pokemon.speed.max() , 15)

# %%
plt.hist(data = pokemon, x = 'speed',bins=bin_width )
plt.show()

# %% [markdown]
# ## Figures, Axes and Subplots

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-08-03%2015.58.16.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-08-03%2015.58.16.png)

# %%
# 하나에 여러개의 plot을 그린다.
plt.subplot(1,2,1)
bin_width = np.arange(5,160,15)
plt.hist(data = pokemon, x = 'speed',bins=bin_width )

plt.subplot(1,2,2)
bin_width = np.arange(5,160,10)
plt.hist(data = pokemon, x = 'speed',bins=bin_width )

plt.show()

# %% [markdown]
# # Bivariate (여러개의 변수) Visualization  방법

# %% [markdown]
# ## Scatterplots

# %%
# 두개의 관계를 파악하고 싶을때
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
fuel_econ = pd.read_csv('fuel_econ.csv')

# %%
fuel_econ
# Out:
#          id        make             model  year           VClass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fuelType  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %%
plt.scatter(data = fuel_econ, x = 'displ', y = 'comb')
plt.xlabel('Displacement (L)')
plt.ylabel('Combined Fuel Eff. (Mile per Gallon)')
plt.show()

# %%
fuel_econ.loc[ :,['displ','comb']].corr()
# Out:
#           displ      comb
# displ  1.000000 -0.758397
# comb  -0.758397  1.000000

# %%
fuel_econ.year.unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018], dtype=int64)

# %%
plt.scatter(data = fuel_econ, x = 'year', y = 'comb')
plt.show()

# %% [markdown]
# ## 스케터는, 여러 데이터가 한군데 뭉치면 보기 힘들다. 이를 어떻게 해결할것인가

# %% [markdown]
# ## Heat Maps : 밀도를 나타내는데 좋다.

# %%
plt.hist2d(data = fuel_econ, x = 'displ', y = 'comb', cmin= 0.5, cmap = 'viridis_r')
plt.colorbar()
plt.xlabel('Displacement')
plt.ylabel('Mile per Gallon ')
plt.show()

# %%
fuel_econ[['displ', 'comb']].describe()
# Out:
#              displ         comb
# count  3929.000000  3929.000000
# mean      2.950573    24.791339
# std       1.305901     6.003246
# min       0.600000    12.821700
# 25%       2.000000    20.658100
# 50%       2.500000    24.000000
# 75%       3.600000    28.227100
# max       7.000000    57.782400

# %%
bins_x = np.arange(0.5, 7.0 + 0.3, 0.3)

# %%
bins_x
# Out:
# array([0.5, 0.8, 1.1, 1.4, 1.7, 2. , 2.3, 2.6, 2.9, 3.2, 3.5, 3.8, 4.1,
#        4.4, 4.7, 5. , 5.3, 5.6, 5.9, 6.2, 6.5, 6.8, 7.1])

# %% [markdown]
# ## 한글 처리를 위해서는, 아래 코드를 실행하시면 됩니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# ## 문제 1. 위에서 city 와 highway 에서의 연비 관계를 분석하세요. (스케터 이용)

# %%
plt.scatter(data = fuel_econ, x = 'city', y = 'highway')
plt.xlabel('도심')
plt.ylabel('고속도로 ')
plt.show()

# %%
sb.regplot(data = fuel_econ, x = 'city', y = 'highway')
plt.xlabel('도심')
plt.ylabel('고속도로 ')
plt.show()

# %% [markdown]
# ## 문제 2. 엔진 크기와 이산화탄소 배출량의 관계를 분석하세요. (히트맵으로)   displ 이 엔진사이즈이고, co2 가 이산화탄소 배출량입니다.  트랜드를 분석하세요

# %%
plt.hist2d(data = fuel_econ, x = 'displ', y= 'co2', cmin = 0.5, cmap='viridis_r')
plt.colorbar()
plt.show()

# %% [markdown]
# ## BOXPLOT

# %%
sb.boxplot(data=fuel_econ, x= 'year', y='comb', color = 'skyblue')
plt.show()

# %% [markdown]
# # MARKERS AND LINE STYLES
#
# - plt.plot(x, y, linestyle='--', marker='o', color='b')
# - plt.plot(x, y, '--bo')
#
#
# ![image.png](attachment:image.png)
#
# Reference: https://stackoverflow.com/questions/8409095/matplotlib-set-markers-for-individual-points-on-a-line

# %%
t = np.arange(0,5,0.2)

# %%
plt.plot(t, t**2, color='r', lw = 5, ls = '--')
plt.show()

# %% [markdown]
# # KEEP UP THE GOOD WORK!
